# %%
import torch as t
from torch_timeseries.dataset import ETTh1
from torch_timeseries.dataloader import SlidingWindowTS, StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from .. import GAN
#       2 import torch as t
#       3 from torch_timeseries.dataset import ETTh1
#
# ImportError: attempted relative import with no known parent package
